# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 23.3.2 is available.
# You should consider upgrading via the 'C:\Users\SSAFY\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 23.3.2 is available.
# You should consider upgrading via the 'C:\Users\SSAFY\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
import csv
import numpy as np
import pandas as pd
# Out:
# C:\Users\SSAFY\AppData\Local\Temp\ipykernel_11444\3927477258.py:3: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
csv_path = "data/NFLX.csv"
df = pd.read_csv(csv_path, usecols=range(0,5))
df
# Out:
#             Date        Open        High         Low       Close
# 0     2018-02-05  262.000000  267.899994  250.029999  254.259995
# 1     2018-02-06  247.699997  266.700012  245.000000  265.720001
# 2     2018-02-07  266.579987  272.450012  264.329987  264.559998
# 3     2018-02-08  267.079987  267.619995  250.000000  250.100006
# 4     2018-02-09  253.850006  255.800003  236.110001  249.470001
# ...          ...         ...         ...         ...         ...
# 1004  2022-01-31  401.970001  427.700012  398.200012  427.140015
# 1005  2022-02-01  432.959991  458.480011  425.540009  457.130005
# 1006  2022-02-02  448.250000  451.980011  426.480011  429.480011
# 1007  2022-02-03  421.440002  429.260010  404.279999  405.600006
# 1008  2022-02-04  407.309998  412.769989  396.640015  410.170013
#
# [1009 rows x 5 columns]

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df = df.query('2021 <= Date.dt.year')
df
# Out:
#            Date        Open        High         Low       Close
# 733  2021-01-04  539.000000  540.799988  515.090027  522.859985
# 734  2021-01-05  521.549988  526.780029  515.890015  520.799988
# 735  2021-01-06  511.970001  513.099976  499.500000  500.489990
# 736  2021-01-07  508.279999  516.440002  506.420013  508.890015
# 737  2021-01-08  511.309998  513.239990  504.510010  510.399994
# ...         ...         ...         ...         ...         ...
# 1004 2022-01-31  401.970001  427.700012  398.200012  427.140015
# 1005 2022-02-01  432.959991  458.480011  425.540009  457.130005
# 1006 2022-02-02  448.250000  451.980011  426.480011  429.480011
# 1007 2022-02-03  421.440002  429.260010  404.279999  405.600006
# 1008 2022-02-04  407.309998  412.769989  396.640015  410.170013
#
# [276 rows x 5 columns]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df['Date'], df['Close'])
plt.title('NFLX Close Price')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.xticks(rotation=45)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
print("최고 종가: ", df['Close'].max())
print("최저 종가: ", df['Close'].min())
# Out:
# 최고 종가:  691.690002
# 최저 종가:  359.700012

# %%
df['year'] = df['Date'].dt.year
df['month'] = df['Date'].dt.month

df1 = df.groupby(['year', 'month']).mean().reset_index()

plt.plot(df1['Date'], df1['Close'])
plt.title('High, Low, and Close Prices since January 2002')
plt.xlabel('Date')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.show
# Out:
# C:\Users\SSAFY\AppData\Local\Temp\ipykernel_11444\2246969278.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['year'] = df['Date'].dt.year
# C:\Users\SSAFY\AppData\Local\Temp\ipykernel_11444\2246969278.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['month'] = df['Date'].dt.month
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df2 = df.query('2022 <= Date.dt.year')

plt.plot(df2['Date'], df2['Close'], label='Close')
plt.plot(df2['Date'], df2['Low'], label='Low')
plt.plot(df2['Date'], df2['High'], label='High')
plt.legend()
plt.title('Monthly Average Close Price')
plt.xlabel('Date')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
